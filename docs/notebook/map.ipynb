# %%
import pydarn.plot as pplot
import matplotlib.pyplot as plt
from pydarn.radar import *
from utils import *
from datetime import datetime as dt
from datetime import timedelta

# %%
# This part can be skipped if you are using davitpy-notebook
import sys
sys.path.append('../..')
import os
os.environ['RSTPATH'] = '/davit/lib/rst/rst'

# %%
figure(figsize=(10,10))
# Plot map
subplot(221)
m1 = pplot.map(hemi='north')
pplot.overlayRadar(m1, fontSize=6, all=True, markerSize=5)
subplot(222)
m2 = pplot.map(hemi='south')
pplot.overlayRadar(m2, fontSize=6, all=True, markerSize=5)
subplot(223)
m1 = pplot.map(hemi='north', boundingLat=40., lon_0=0.)
subplot(224)
lon_0 = -80.
m2 = pplot.map(hemi='north', limits=[10.,lon_0-35.,60.,lon_0+105.], lon_0=lon_0)
# Out:
# /usr/local/lib/python2.7/dist-packages/mpl_toolkits/__init__.py:2: UserWarning: Module dap was already imported from None, but /usr/lib/python2.7/dist-packages is being added to sys.path
#   __import__('pkg_resources').declare_namespace(__name__)

# %%
# Set map
figure(figsize=(10,10))
lon_0 = -70.
m = pplot.map(hemi='north', limits=[10.,lon_0-35.,60.,lon_0+105.], lon_0=lon_0)
codes = ['wal','bks','fhe','fhw','cve','cvw']
# Plotting some radars
pplot.overlayRadar(m, fontSize=12, codes=codes)
# Plot radar fov
pplot.overlayFov(m, codes=codes, maxGate=75, fovColor=120)

# %%
# To get the field of view (with the most recent radar configuration)
radNet = network()
site = radNet.getRadarByCode('cvw').getSiteByDate(dt.utcnow())
radFov = fov(site=site)
