# %%
import pydarn.plot as pplot
import matplotlib.pyplot as plt
from pydarn.radar import *
from utils import *
from datetime import datetime as dt
from datetime import timedelta

# %%
figure(figsize=(10,10))
# Plot map
subplot(121)
m1 = pplot.map(hemi='north', gridLabels=False)
pplot.overlayRadar(m1, fontSize=6, all=True, markerSize=5)
subplot(122)
m2 = pplot.map(hemi='south', gridLabels=False)
pplot.overlayRadar(m2, fontSize=6, all=True, markerSize=5)

# %%
# Set map
figure(figsize=(10,10))
lon_0 = -70.
m = pplot.map(hemi='north', limits=[20.,lon_0-35.,75.,lon_0], lon_0=lon_0)
radar = 'bks'
# Plotting some radars
pplot.overlayRadar(m, fontSize=12, codes=radar)
# Plot radar fov
pplot.overlayFov(m, codes=radar, maxGate=75, beams=[0,4,7,8,23])

# %%
# Set map
fig = figure(figsize=(10,10))
lon_0 = -70.
m = pplot.map(hemi='north', limits=[20, lon_0-40., 35, lon_0+140.], lon_0=lon_0)
codes = ['wal','fhe','fhw','cve','cvw','hok','ade','adw','bks']
# Plotting some radars
pplot.overlayRadar(m, fontSize=12, codes=codes)
# Plot radar fov
pplot.overlayFov(m, codes=codes[:-1], maxGate=75)#, fovColor=(.8,.9,.9))
pplot.overlayFov(m, codes=codes[-1], maxGate=75, fovColor=(.8,.7,.8), fovAlpha=.5)
fig.tight_layout(pad=2)
rcParams.update({'font.size': 14})
#fig.savefig('/home/sebastien/Desktop/rad_fov.pdf')

# %%
# Set map
figure(figsize=(8,8))
lon_0 = -70.
m = pplot.map(hemi='north', boundingLat=35., lon_0=lon_0)

# Go through each radar
codes = ['gbr','kap','sas','pgr', \
        'kod','sto','pyk','han', \
        'ksr','cve','cvw','wal', \
        'bks','hok','fhw','fhe', \
        'inv','rkn']
beams = [[3,4,6],[10,11,13],[2,3,5],[12,13,15], \
        [2,3,5],[12,13,15],[0,1,3],[5,6,8], \
        [12,13,15],[0,1,3],[19,20,22],[0,1,3], \
        [12,13,15],[0,1,3],[18,19,21],[0,1,3],\
        [6,7,9],[6,7,9]]
for i,rad in enumerate(codes):
    # Plot radar
    pplot.overlayRadar(m, fontSize=12, codes=rad)
    # Plot radar fov
    pplot.overlayFov(m, codes=rad, maxGate=75, beams=beams[i])
#savefig('rbsp_beams.pdf')

# %%
# To get the field of view (with the most recent radar configuration)
def test2():
    radNet = network()  
    radar = radNet.getRadarByCode('bks')
    site1 = radar.getSiteByDate(dt.utcnow())
    radFov1 = fov(site=site1)
    radar = radNet.getRadarByCode('wal')
    site2 = radar.getSiteByDate(dt.utcnow())
    radFov2 = fov(site=site2)
profileUtils.run('test2()')
# Out:
#    Ordered by: cumulative time
#
# Function                                                     called...
#                                                                  ncalls  tottime  cumtime
# <string>:1(<module>)                                         ->       1    0.000    3.958  <ipython-input-10-338bcc63db62>:2(test2)
# <ipython-input-10-338bcc63db62>:2(test2)                     ->       1    0.049    0.559  __init__.py:38(__init__)
#                                                                       2    0.000    0.000  __init__.py:134(getRadarByCode)
#                                                                       2    0.000    0.000  __init__.py:309(getSiteByDate)
#                                                                       2    0.110    3.399  radFov.py:58(__init__)
#                                                                       2    0.000    0.000  {built-in method utcnow}
# radFov.py:58(__init__)                                       ->       4    0.000    0.000  __init__.py:353(__len__)
#                                                                   11100    0.532    3.281  radFov.py:248(calcFieldPnt)
#                                                                       4    0.000    0.000  radFov.py:346(slantRange)
#                                                                   11110    0.007    0.007  {isinstance}
#                                                                       4    0.000    0.000  {numpy.core.multiarray.arange}
#                                                                       6    0.000    0.000  {numpy.core.multiarray.array}
#                                                                      12    0.000    0.000  {numpy.core.multiarray.zeros}
# radFov.py:248(calcFieldPnt)                                  ->   11100    0.084    0.098  geoPack.py:28(geodToGeoc)
#                                                                   21226    0.359    2.403  geoPack.py:307(calcDistPnt)
#                                                                   21226    0.202    0.237  radFov.py:375(calcAzOffBore)
#                                                                   21226    0.003    0.003  {abs}
#                                                                   21226    0.006    0.006  {math.asin}
#                                                                   21226    0.002    0.002  {math.degrees}
# geoPack.py:307(calcDistPnt)                                  ->   21226    0.158    0.183  geoPack.py:28(geodToGeoc)
#                                                                   21226    0.242    0.465  geoPack.py:69(geodToGeocAzEl)
#                                                                   21226    0.279    0.305  geoPack.py:138(gspToGcar)
#                                                                   21226    0.463    0.785  geoPack.py:180(gcarToLcar)
#                                                                   21226    0.278    0.307  geoPack.py:253(lspToLcar)
# geoPack.py:180(gcarToLcar)                                   ->   21226    0.259    0.290  geoPack.py:138(gspToGcar)
#                                                                   21226    0.003    0.003  {isinstance}
#                                                                   84904    0.012    0.012  {math.cos}
#                                                                   42452    0.005    0.005  {math.radians}
#                                                                   84904    0.013    0.013  {math.sin}
# geoPack.py:138(gspToGcar)                                    ->   42452    0.006    0.006  {isinstance}
#                                                                   21226    0.006    0.006  {math.asin}
#                                                                   21226    0.007    0.007  {math.atan2}
#                                                                   63678    0.010    0.010  {math.cos}
#                                                                   42452    0.004    0.004  {math.degrees}
#                                                                  106130    0.012    0.012  {math.radians}
#                                                                   42452    0.007    0.007  {math.sin}
#                                                                   21226    0.005    0.005  {math.sqrt}
# __init__.py:38(__init__)                                     ->      48    0.003    0.010  __init__.py:260(__init__)
#                                                                    1560    0.073    0.335  dataset.py:271(__getitem__)
#                                                                       1    0.000    0.000  files.py:134(__init__)
#                                                                       1    0.000    0.000  files.py:168(close)
#                                                                    1610    0.016    0.152  group.py:122(__getitem__)
#                                                                     168    0.001    0.012  {built-in method strptime}
#                                                                       1    0.000    0.000  {len}
#                                                                      48    0.000    0.000  {method 'append' of 'list' objects}
#                                                                       1    0.000    0.000  {method 'split' of 'str' objects}
#                                                                      48    0.000    0.000  {numpy.core.multiarray.where}
#                                                                       1    0.000    0.000  {range}
# geoPack.py:69(geodToGeocAzEl)                                ->   21226    0.146    0.169  geoPack.py:28(geodToGeoc)
#                                                                   21226    0.004    0.004  {isinstance}
#                                                                   21226    0.007    0.007  {math.atan2}
#                                                                   21226    0.004    0.004  {math.atan}
#                                                                  106130    0.014    0.014  {math.cos}
#                                                                   42452    0.004    0.004  {math.degrees}
#                                                                   63678    0.009    0.009  {math.radians}
#                                                                   84904    0.010    0.010  {math.sin}
#                                                                   21226    0.003    0.003  {math.sqrt}
# geoPack.py:28(geodToGeoc)                                    ->   53552    0.008    0.008  {isinstance}
#                                                                   53552    0.010    0.010  {math.atan}
#                                                                   53552    0.005    0.005  {math.degrees}
#                                                                  107104    0.013    0.013  {math.radians}
#                                                                   53552    0.009    0.009  {math.sin}
#                                                                   53552    0.007    0.007  {math.sqrt}
#                                                                   53552    0.012    0.012  {math.tan}
# dataset.py:271(__getitem__)                                  ->    4680    0.002    0.002  base.py:156(id)
#                                                                    4800    0.080    0.082  dataset.py:118(shape)
#                                                                    1560    0.002    0.003  dataset.py:285(<genexpr>)
#                                                                    3120    0.002    0.003  dataset.py:286(<genexpr>)
#                                                                    1560    0.003    0.005  dataset.py:308(readtime_dtype)
#                                                                    1560    0.015    0.113  selections.py:29(select)
#                                                                    1560    0.001    0.002  selections.py:168(nselect)
#                                                                    1728    0.000    0.000  selections.py:239(mshape)
#                                                                    1560    0.014    0.014  {h5py.h5s.create_simple}
#                                                                    1560    0.006    0.006  {h5py.h5t.py_create}
#                                                                    1560    0.002    0.002  {isinstance}
#                                                                    4920    0.001    0.001  {len}
#                                                                    1560    0.028    0.028  {method 'read' of 'h5py.h5d.DatasetID' objects}
# geoPack.py:253(lspToLcar)                                    ->   21226    0.003    0.003  {isinstance}
#                                                                   63678    0.009    0.009  {math.cos}
#                                                                  106130    0.011    0.011  {math.radians}
#                                                                   42452    0.006    0.006  {math.sin}
# radFov.py:375(calcAzOffBore)                                 ->   21226    0.004    0.004  {math.atan}
#                                                                   42452    0.007    0.007  {math.cos}
#                                                                   21226    0.002    0.002  {math.degrees}
#                                                                  106130    0.011    0.011  {math.radians}
#                                                                   63678    0.008    0.008  {math.sin}
#                                                                   21226    0.003    0.003  {math.sqrt}
# group.py:122(__getitem__)                                    ->    1610    0.001    0.001  base.py:66(_lapl)
#                                                                    1610    0.003    0.004  base.py:78(_e)
#                                                                    1610    0.001    0.001  base.py:156(id)
#                                                                    1561    0.010    0.058  dataset.py:197(__init__)
#                                                                      49    0.000    0.000  group.py:16(__init__)
#                                                                    1610    0.001    0.001  {h5py.h5i.get_type}
#                                                                    1610    0.070    0.070  {h5py.h5o.open}
#                                                                    1610    0.002    0.002  {isinstance}
# selections.py:29(select)                                     ->    1560    0.009    0.039  selections.py:244(__init__)
#                                                                    1560    0.016    0.056  selections.py:250(__getitem__)
#                                                                    7800    0.004    0.004  {isinstance}
#                                                                    1560    0.000    0.000  {len}
# dataset.py:118(shape)                                        ->    4801    0.002    0.002  base.py:156(id)
# {h5py.h5o.open}                                              ->
# {math.radians}                                               ->
# dataset.py:197(__init__)                                     ->    1561    0.000    0.000  base.py:156(id)
#                                                                    1561    0.002    0.002  base.py:172(__init__)
#                                                                    1561    0.008    0.011  filters.py:156(get_filters)
#                                                                    1561    0.000    0.000  {isinstance}
#                                                                    1561    0.034    0.034  {method 'get_create_plist' of 'h5py.h5d.DatasetID' objects}
# selections.py:250(__getitem__)                               ->    3120    0.001    0.001  selections.py:163(shape)
#                                                                    1728    0.001    0.001  selections.py:267(<genexpr>)
#                                                                    1560    0.012    0.033  selections.py:494(_handle_simple)
#                                                                    1560    0.000    0.000  {isinstance}
#                                                                    1560    0.004    0.004  {method 'select_hyperslab' of 'h5py.h5s.SpaceID' objects}
#                                                                    1560    0.001    0.001  {zip}
# {math.sin}                                                   ->
# {math.cos}                                                   ->
# {isinstance}                                                 ->
# selections.py:244(__init__)                                  ->    1560    0.008    0.028  selections.py:147(__init__)
#                                                                    4680    0.001    0.001  selections.py:163(shape)
#                                                                    1560    0.000    0.000  {len}
# {method 'get_create_plist' of 'h5py.h5d.DatasetID' objects}  ->
# {h5py.h5s.create_simple}                                     ->
# selections.py:494(_handle_simple)                            ->    1560    0.009    0.013  selections.py:471(_expand_ellipsis)
#                                                                    1512    0.001    0.001  selections.py:527(_translate_int)
#                                                                     168    0.000    0.000  selections.py:540(_translate_slice)
#                                                                    1680    0.002    0.002  {isinstance}
#                                                                    1560    0.000    0.000  {len}
#                                                                    6720    0.002    0.002  {method 'append' of 'list' objects}
#                                                                    1560    0.002    0.002  {zip}
# {method 'read' of 'h5py.h5d.DatasetID' objects}              ->
# selections.py:147(__init__)                                  ->    1560    0.019    0.019  {h5py.h5s.create_simple}
#                                                                    1560    0.000    0.000  {len}
#                                                                    1560    0.001    0.001  {method 'select_all' of 'h5py.h5s.SpaceID' objects}
# {math.atan}                                                  ->
# {math.degrees}                                               ->
# {math.sqrt}                                                  ->
# {math.atan2}                                                 ->
# selections.py:471(_expand_ellipsis)                          ->    4680    0.001    0.001  {len}
#                                                                    1560    0.001    0.001  {method 'append' of 'list' objects}
#                                                                     120    0.000    0.000  {method 'extend' of 'list' objects}
#                                                                    1560    0.001    0.002  {sum}
# {math.tan}                                                   ->
# {built-in method strptime}                                   ->     168    0.006    0.010  _strptime.py:295(_strptime)
# filters.py:156(get_filters)                                  ->    1561    0.002    0.002  {method 'get_nfilters' of 'h5py.h5p.PropDCID' objects}
#                                                                    1561    0.001    0.001  {range}
# {math.asin}                                                  ->
# _strptime.py:295(_strptime)                                  ->     168    0.000    0.003  _strptime.py:27(_getlang)
#                                                                     336    0.000    0.000  {len}
#                                                                     168    0.000    0.000  {method 'end' of '_sre.SRE_Match' objects}
#                                                                     168    0.000    0.000  {method 'get' of 'dict' objects}
#                                                                     168    0.001    0.001  {method 'groupdict' of '_sre.SRE_Match' objects}
#                                                                     168    0.000    0.000  {method 'iterkeys' of 'dict' objects}
#                                                                     168    0.001    0.001  {method 'match' of '_sre.SRE_Pattern' objects}
#                                                                     336    0.000    0.000  {method 'toordinal' of 'datetime.date' objects}
#                                                                     168    0.000    0.000  {method 'weekday' of 'datetime.date' objects}
# __init__.py:260(__init__)                                    ->    1536    0.007    0.007  __init__.py:336(__init__)
#                                                                    1536    0.000    0.000  {method 'append' of 'list' objects}
#                                                                      48    0.000    0.000  {range}
# __init__.py:336(__init__)                                    ->
# {h5py.h5t.py_create}                                         ->
# dataset.py:308(readtime_dtype)                               ->    1560    0.002    0.002  dataset.py:288(strip_fields)
#                                                                    1560    0.000    0.000  {len}
# base.py:156(id)                                              ->
# {method 'select_hyperslab' of 'h5py.h5s.SpaceID' objects}    ->
# base.py:78(_e)                                               ->    1610    0.000    0.000  {isinstance}
# {zip}                                                        ->
# {abs}                                                        ->
# {method 'append' of 'list' objects}                          ->
# {len}                                                        ->       1    0.000    0.000  dataset.py:238(__len__)
# _strptime.py:27(_getlang)                                    ->     168    0.000    0.003  locale.py:506(getlocale)
# dataset.py:286(<genexpr>)                                    ->    1560    0.001    0.001  {isinstance}
# dataset.py:285(<genexpr>)                                    ->    1560    0.001    0.001  {isinstance}
# locale.py:506(getlocale)                                     ->     168    0.000    0.002  locale.py:407(_parse_localename)
#                                                                     168    0.000    0.000  {_locale.setlocale}
# {sum}                                                        ->    1560    0.001    0.001  selections.py:474(<genexpr>)
# dataset.py:288(strip_fields)                                 ->
# selections.py:168(nselect)                                   ->    1560    0.001    0.001  {method 'get_select_npoints' of 'h5py.h5s.SpaceID' objects}
# selections.py:163(shape)                                     ->
# {method 'get_nfilters' of 'h5py.h5p.PropDCID' objects}       ->
# locale.py:407(_parse_localename)                             ->     168    0.001    0.002  locale.py:339(normalize)
# base.py:172(__init__)                                        ->
# locale.py:339(normalize)                                     ->     168    0.000    0.000  {isinstance}
#                                                                     336    0.000    0.000  {method 'get' of 'dict' objects}
#                                                                     336    0.000    0.000  {method 'replace' of 'str' objects}
#                                                                     168    0.000    0.000  {method 'translate' of 'str' objects}
# {range}                                                      ->
# selections.py:267(<genexpr>)                                 ->
# selections.py:527(_translate_int)                            ->
# selections.py:474(<genexpr>)                                 ->
# {method 'match' of '_sre.SRE_Pattern' objects}               ->
# {method 'select_all' of 'h5py.h5s.SpaceID' objects}          ->
# {method 'groupdict' of '_sre.SRE_Match' objects}             ->
# {h5py.h5i.get_type}                                          ->
# {method 'get_select_npoints' of 'h5py.h5s.SpaceID' objects}  ->
# base.py:66(_lapl)                                            ->
# selections.py:540(_translate_slice)                          ->     168    0.000    0.000  {method 'indices' of 'slice' objects}
# selections.py:239(mshape)                                    ->
# files.py:134(__init__)                                       ->       1    0.000    0.000  files.py:12(make_fapl)
#                                                                       1    0.000    0.000  files.py:41(make_fid)
#                                                                       1    0.000    0.000  group.py:16(__init__)
#                                                                       1    0.000    0.000  {isinstance}
#                                                                       1    0.000    0.000  {method 'encode' of 'str' objects}
#                                                                       1    0.000    0.000  {sys.getfilesystemencoding}
# files.py:168(close)                                          ->       1    0.000    0.000  base.py:156(id)
#                                                                       1    0.000    0.000  {method 'close' of 'h5py.h5f.FileID' objects}
# {method 'close' of 'h5py.h5f.FileID' objects}                ->
# files.py:41(make_fid)                                        ->       1    0.000    0.000  {h5py.h5f.open}
# {h5py.h5f.open}                                              ->
# {_locale.setlocale}                                          ->
# __init__.py:134(getRadarByCode)                              ->       2    0.000    0.000  __init__.py:141(getRadarBy)
# __init__.py:141(getRadarBy)                                  ->     221    0.000    0.000  {method 'lower' of 'str' objects}
# {method 'replace' of 'str' objects}                          ->
# group.py:16(__init__)                                        ->      50    0.000    0.000  base.py:172(__init__)
#                                                                      50    0.000    0.000  {isinstance}
# {numpy.core.multiarray.where}                                ->
# {method 'get' of 'dict' objects}                             ->
# {method 'indices' of 'slice' objects}                        ->
# radFov.py:346(slantRange)                                    ->
# {method 'end' of '_sre.SRE_Match' objects}                   ->
# files.py:12(make_fapl)                                       ->       1    0.000    0.000  {h5py.h5p.create}
#                                                                       1    0.000    0.000  {method 'set_fclose_degree' of 'h5py.h5p.PropFAID' objects}
# {h5py.h5p.create}                                            ->
# {method 'toordinal' of 'datetime.date' objects}              ->
# {numpy.core.multiarray.zeros}                                ->
# {numpy.core.multiarray.array}                                ->
# {method 'translate' of 'str' objects}                        ->
# {method 'iterkeys' of 'dict' objects}                        ->
# {method 'extend' of 'list' objects}                          ->
# __init__.py:309(getSiteByDate)                               ->       2    0.000    0.000  {range}
# dataset.py:238(__len__)                                      ->       1    0.000    0.000  dataset.py:248(len)
# {method 'weekday' of 'datetime.date' objects}                ->
# dataset.py:248(len)                                          ->       1    0.000    0.000  dataset.py:118(shape)
#                                                                       1    0.000    0.000  {len}
# {method 'lower' of 'str' objects}                            ->
# {numpy.core.multiarray.arange}                               ->
# {built-in method utcnow}                                     ->
# {method 'encode' of 'str' objects}                           ->
# {method 'set_fclose_degree' of 'h5py.h5p.PropFAID' objects}  ->
# {method 'split' of 'str' objects}                            ->
# __init__.py:353(__len__)                                     ->
# {sys.getfilesystemencoding}                                  ->
# {method 'disable' of '_lsprof.Profiler' objects}             ->
# <pstats.Stats instance at 0x10d5765f0>
