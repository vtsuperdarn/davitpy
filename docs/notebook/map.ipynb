# %%
import pydarn.plot as pplot
import matplotlib.pyplot as plt
from pydarn.radar import *
from utils import *
from datetime import datetime as dt
from datetime import timedelta

# %%
# This part can be skipped if you are using davitpy-notebook
import sys
sys.path.append('../..')
import os
os.environ['RSTPATH'] = '/davit/lib/rst/rst'

# %%
figure(figsize=(10,10))
# Plot map
subplot(121)
m1 = pplot.map(hemi='north')
pplot.overlayRadar(m1, fontSize=6, all=True, markerSize=5)
subplot(122)
m2 = pplot.map(hemi='south')
pplot.overlayRadar(m2, fontSize=6, all=True, markerSize=5)

# %%
# Set map
figure(figsize=(10,10))
lon_0 = -70.
m = pplot.map(hemi='north', limits=[20.,lon_0-35.,75.,lon_0], lon_0=lon_0)
radar = 'bks'
# Plotting some radars
pplot.overlayRadar(m, fontSize=12, codes=radar)
# Plot radar fov
pplot.overlayFov(m, codes=radar, maxGate=75, beams=[0,4,7,8,23])

# %%
# Set map
figure(figsize=(10,10))
lon_0 = -70.
m = pplot.map(hemi='north', limits=[10.,lon_0-35.,60.,lon_0+105.], lon_0=lon_0)
codes = ['wal','fhe','fhw','cve','cvw','bks']
# Plotting some radars
pplot.overlayRadar(m, fontSize=12, codes=codes)
# Plot radar fov
pplot.overlayFov(m, codes=codes[:-1], maxGate=75, fovColor=120)
pplot.overlayFov(m, codes=codes[-1], maxGate=75, fovColor=100, fovAlpha=.5)

# %%
# Set map
figure(figsize=(20,20))
lon_0 = -70.
m = pplot.map(hemi='north', boundingLat=35., lon_0=lon_0)

# Go through each radar
codes = ['gbr','kap','sas','pgr', \
        'kod','sto','pyk','han', \
        'ksr','cve','cvw','wal', \
        'bks','hok','fhw','fhe', \
        'inv','rkn']
beams = [[3,4,6],[10,11,13],[2,3,5],[12,13,15], \
        [2,3,5],[12,13,15],[0,1,3],[5,6,8], \
        [12,13,15],[0,1,3],[19,20,22],[0,1,3], \
        [12,13,15],[0,1,3],[18,19,21],[0,1,3],\
        [6,7,9],[6,7,9]]
for i,rad in enumerate(codes):
    # Plot radar
    pplot.overlayRadar(m, fontSize=12, codes=rad)
    # Plot radar fov
    pplot.overlayFov(m, codes=rad, maxGate=75, beams=beams[i])
savefig('rbsp_beams.pdf')

# %%
# To get the field of view (with the most recent radar configuration)
def test2():
    radNet = network()  
    radar = radNet.getRadarByCode('bks')
    site1 = radar.getSiteByDate(dt.utcnow())
    radFov1 = fov(site=site1)
    radar = radNet.getRadarByCode('wal')
    site2 = radar.getSiteByDate(dt.utcnow())
    radFov2 = fov(site=site2)
profileUtils.run('test2()')
# Out:
#    Ordered by: cumulative time
#
# Function                                          called...
#                                                       ncalls  tottime  cumtime
# <string>:1(<module>)                              ->       1    0.000    2.369  <ipython-input-14-338bcc63db62>:2(test2)
# <ipython-input-14-338bcc63db62>:2(test2)          ->       2    0.048    1.864  radFov.py:57(__init__)
#                                                            1    0.001    0.505  radNetwork.py:29(__init__)
#                                                            2    0.000    0.000  radNetwork.py:113(getRadarByCode)
#                                                            2    0.000    0.000  radNetwork.py:225(getSiteByDate)
#                                                            2    0.000    0.000  {built-in method utcnow}
# radFov.py:57(__init__)                            ->   11100    0.236    1.811  radFov.py:241(calcFieldPnt)
#                                                            4    0.000    0.000  radFov.py:338(slantRange)
#                                                            4    0.000    0.000  radNetwork.py:271(__len__)
#                                                        11110    0.005    0.005  {isinstance}
#                                                            4    0.000    0.000  {numpy.core.multiarray.arange}
#                                                            6    0.000    0.000  {numpy.core.multiarray.array}
#                                                           12    0.000    0.000  {numpy.core.multiarray.zeros}
# radFov.py:241(calcFieldPnt)                       ->   11100    0.053    0.066  geoPack.py:27(geodToGeoc)
#                                                        21216    0.180    1.342  geoPack.py:306(calcDistPnt)
#                                                        21216    0.127    0.158  radFov.py:366(calcAzOffBore)
#                                                        21216    0.002    0.002  {abs}
#                                                        21216    0.005    0.005  {math.asin}
#                                                        21216    0.002    0.002  {math.degrees}
# geoPack.py:306(calcDistPnt)                       ->   21216    0.099    0.121  geoPack.py:27(geodToGeoc)
#                                                        21216    0.126    0.284  geoPack.py:68(geodToGeocAzEl)
#                                                        21216    0.157    0.178  geoPack.py:137(gspToGcar)
#                                                        21216    0.277    0.395  geoPack.py:179(gcarToLcar)
#                                                        21216    0.161    0.183  geoPack.py:252(lspToLcar)
# radNetwork.py:29(__init__)                        ->      47    0.001    0.004  radNetwork.py:176(__init__)
#                                                            1    0.000    0.011  radNetwork.py:314(radarRead)
#                                                           47    0.007    0.489  radNetwork.py:366(hdwRead)
#                                                           48    0.000    0.000  {len}
#                                                           47    0.000    0.000  {method 'append' of 'list' objects}
#                                                           48    0.000    0.000  {range}
# radNetwork.py:366(hdwRead)                        ->      47    0.000    0.000  UserDict.py:18(__getitem__)
#                                                         4819    0.025    0.443  shlex.py:274(split)
#                                                           24    0.000    0.000  timeUtils.py:85(timeYrsecToDate)
#                                                         4819    0.000    0.000  {len}
#                                                         1065    0.000    0.000  {method 'append' of 'list' objects}
#                                                           47    0.000    0.000  {method 'close' of 'file' objects}
#                                                           47    0.001    0.001  {method 'readlines' of 'file' objects}
#                                                           47    0.037    0.037  {open}
# shlex.py:274(split)                               ->    4866    0.013    0.015  shlex.py:23(__init__)
#                                                         4866    0.001    0.001  shlex.py:265(__iter__)
#                                                        47919    0.020    0.409  shlex.py:268(next)
# shlex.py:268(next)                                ->   47919    0.030    0.389  shlex.py:88(get_token)
# geoPack.py:179(gcarToLcar)                        ->   21216    0.071    0.093  geoPack.py:137(gspToGcar)
#                                                        21216    0.002    0.002  {isinstance}
#                                                        84864    0.010    0.010  {math.cos}
#                                                        42432    0.003    0.003  {math.radians}
#                                                        84864    0.011    0.011  {math.sin}
# shlex.py:88(get_token)                            ->   47919    0.331    0.360  shlex.py:120(read_token)
# shlex.py:120(read_token)                          ->  276190    0.029    0.029  {method 'read' of 'cStringIO.StringI' objects}
# geoPack.py:27(geodToGeoc)                         ->   53532    0.005    0.005  {isinstance}
#                                                        53532    0.011    0.011  {math.atan}
#                                                        53532    0.004    0.004  {math.degrees}
#                                                       107064    0.007    0.007  {math.radians}
#                                                        53532    0.007    0.007  {math.sin}
#                                                        53532    0.005    0.005  {math.sqrt}
#                                                        53532    0.015    0.015  {math.tan}
# geoPack.py:68(geodToGeocAzEl)                     ->   21216    0.092    0.113  geoPack.py:27(geodToGeoc)
#                                                        21216    0.002    0.002  {isinstance}
#                                                        21216    0.008    0.008  {math.atan2}
#                                                        21216    0.003    0.003  {math.atan}
#                                                       106080    0.012    0.012  {math.cos}
#                                                        42432    0.003    0.003  {math.degrees}
#                                                        63648    0.004    0.004  {math.radians}
#                                                        84864    0.009    0.009  {math.sin}
#                                                        21216    0.002    0.002  {math.sqrt}
# geoPack.py:137(gspToGcar)                         ->   42432    0.004    0.004  {isinstance}
#                                                        21216    0.005    0.005  {math.asin}
#                                                        21216    0.008    0.008  {math.atan2}
#                                                        63648    0.008    0.008  {math.cos}
#                                                        42432    0.003    0.003  {math.degrees}
#                                                       106080    0.007    0.007  {math.radians}
#                                                        42432    0.005    0.005  {math.sin}
#                                                        21216    0.003    0.003  {math.sqrt}
# geoPack.py:252(lspToLcar)                         ->   21216    0.002    0.002  {isinstance}
#                                                        63648    0.008    0.008  {math.cos}
#                                                       106080    0.007    0.007  {math.radians}
#                                                        42432    0.006    0.006  {math.sin}
# radFov.py:366(calcAzOffBore)                      ->   21216    0.005    0.005  {math.atan}
#                                                        42432    0.006    0.006  {math.cos}
#                                                        21216    0.002    0.002  {math.degrees}
#                                                       106080    0.008    0.008  {math.radians}
#                                                        63648    0.008    0.008  {math.sin}
#                                                        21216    0.002    0.002  {math.sqrt}
# {math.sin}                                        ->
# {math.cos}                                        ->
# {open}                                            ->
# {math.radians}                                    ->
# {method 'read' of 'cStringIO.StringI' objects}    ->
# {isinstance}                                      ->
# {math.atan}                                       ->
# {math.atan2}                                      ->
# {math.tan}                                        ->
# shlex.py:23(__init__)                             ->    4866    0.001    0.001  {cStringIO.StringIO}
#                                                         4866    0.001    0.001  {isinstance}
# {math.degrees}                                    ->
# {math.sqrt}                                       ->
# radNetwork.py:314(radarRead)                      ->       1    0.000    0.000  UserDict.py:18(__getitem__)
#                                                           94    0.000    0.000  parseDate.py:2(parseDate)
#                                                           47    0.000    0.007  shlex.py:274(split)
#                                                           94    0.000    0.000  {len}
#                                                          423    0.000    0.000  {method 'append' of 'list' objects}
#                                                            1    0.000    0.000  {method 'close' of 'file' objects}
#                                                            1    0.000    0.000  {method 'readlines' of 'file' objects}
#                                                            1    0.004    0.004  {open}
# {math.asin}                                       ->
# radNetwork.py:176(__init__)                       ->    1504    0.002    0.002  radNetwork.py:254(__init__)
#                                                         1504    0.000    0.000  {method 'append' of 'list' objects}
#                                                           47    0.000    0.000  {range}
# radNetwork.py:254(__init__)                       ->
# {abs}                                             ->
# {method 'readlines' of 'file' objects}            ->
# {cStringIO.StringIO}                              ->
# shlex.py:265(__iter__)                            ->
# {len}                                             ->
# {method 'close' of 'file' objects}                ->
# parseDate.py:2(parseDate)                         ->     188    0.000    0.000  {isinstance}
#                                                          282    0.000    0.000  {len}
#                                                           94    0.000    0.000  {range}
# {method 'append' of 'list' objects}               ->
# {numpy.core.multiarray.zeros}                     ->
# timeUtils.py:85(timeYrsecToDate)                  ->
# radNetwork.py:113(getRadarByCode)                 ->       2    0.000    0.000  radNetwork.py:120(getRadarBy)
# radNetwork.py:120(getRadarBy)                     ->     221    0.000    0.000  {method 'lower' of 'str' objects}
#                                                           47    0.000    0.000  {range}
# radFov.py:338(slantRange)                         ->
# {range}                                           ->
# {numpy.core.multiarray.array}                     ->
# UserDict.py:18(__getitem__)                       ->
# {method 'lower' of 'str' objects}                 ->
# radNetwork.py:225(getSiteByDate)                  ->       2    0.000    0.000  {range}
# {numpy.core.multiarray.arange}                    ->
# {built-in method utcnow}                          ->
# radNetwork.py:271(__len__)                        ->
# {method 'disable' of '_lsprof.Profiler' objects}  ->
# <pstats.Stats instance at 0x32f8050>

# %%
lat,lon,d,i,h,x,y,z,f = igrf11(1,2012,300.,0,40.,41.,1.,270.,271.,1.)
