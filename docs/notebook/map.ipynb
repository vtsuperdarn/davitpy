# %%
import sys
sys.path.append('/davitpy')
import pydarn.plot as pplot
import matplotlib.pyplot as plt
from pydarn.radar import *
from utils import *
from datetime import datetime as dt
from datetime import timedelta
# Out:
# Updated radar information in /davitpy/pydarn/radar/radars.hdf5
# /usr/local/lib/python2.7/dist-packages/mpl_toolkits/__init__.py:2: UserWarning: Module dap was already imported from None, but /usr/lib/python2.7/dist-packages is being added to sys.path
#   __import__('pkg_resources').declare_namespace(__name__)

# %%
figure(figsize=(15,10))
# Plot map
subplot(121)
m1 = pplot.map(hemi='north', gridLabels=False)
pplot.overlayRadar(m1, fontSize=8, all=True, markerSize=5)
subplot(122)
m2 = pplot.map(hemi='south', gridLabels=False)
pplot.overlayRadar(m2, fontSize=8, all=True, markerSize=5)

# %%
# Set map
figure(figsize=(10,10))
lon_0 = -70.
m = pplot.map(hemi='north', limits=[20.,lon_0-35.,75.,lon_0], lon_0=lon_0)
radar = 'bks'
# Plotting some radars
pplot.overlayRadar(m, fontSize=12, codes=radar)
# Plot radar fov
pplot.overlayFov(m, codes=radar, maxGate=75, beams=[0,4,7,8,23])

# %%
# Set map
fig = figure(figsize=(10,10))
lon_0 = -70.
m = pplot.map(hemi='north', limits=[20, lon_0-40., 35, lon_0+140.], lon_0=lon_0)
codes = ['wal','fhe','fhw','cve','cvw','hok','ade','adw','bks']
# Plotting some radars
pplot.overlayRadar(m, fontSize=12, codes=codes)
# Plot radar fov
pplot.overlayFov(m, codes=codes[:-1], maxGate=75)#, fovColor=(.8,.9,.9))
pplot.overlayFov(m, codes=codes[-1], maxGate=75, fovColor=(.8,.7,.8), fovAlpha=.5)
fig.tight_layout(pad=2)
rcParams.update({'font.size': 14})
#fig.savefig('/home/sebastien/Desktop/rad_fov.pdf')

# %%
# Set map
figure(figsize=(8,8))
lon_0 = -70.
m = pplot.map(hemi='north', boundingLat=35., lon_0=lon_0)

# Go through each radar
codes = ['gbr','kap','sas','pgr', \
        'kod','sto','pyk','han', \
        'ksr','cve','cvw','wal', \
        'bks','hok','fhw','fhe', \
        'inv','rkn']
beams = [[3,4,6],[10,11,13],[2,3,5],[12,13,15], \
        [2,3,5],[12,13,15],[0,1,3],[5,6,8], \
        [12,13,15],[0,1,3],[19,20,22],[0,1,3], \
        [12,13,15],[0,1,3],[18,19,21],[0,1,3],\
        [6,7,9],[6,7,9]]
for i,rad in enumerate(codes):
    # Plot radar
    pplot.overlayRadar(m, fontSize=12, codes=rad)
    # Plot radar fov
    pplot.overlayFov(m, codes=rad, maxGate=75, beams=beams[i])
#savefig('rbsp_beams.pdf')

# %%
# To get the field of view (with the most recent radar configuration)
def test2():
    #radNet = network()  
    #radar = radNet.getRadarByCode('bks')
    #site1 = radar.getSiteByDate(dt.utcnow())
    site1 = site(code='bks')
    radFov1 = fov(site=site1)
profileUtils.run('test2()')
# Out:
#    Ordered by: cumulative time
#
# Function                                                                 called...
#                                                                              ncalls  tottime  cumtime
# <string>:1(<module>)                                                     ->       1    0.000    2.130  <ipython-input-6-bf03d040dce4>:2(test2)
# <ipython-input-6-bf03d040dce4>:2(test2)                                  ->       1    0.000    0.013  __init__.py:526(__init__)
#                                                                                   1    0.029    2.117  radFov.py:58(__init__)
#                                                                                   3    0.000    0.000  weakref.py:48(remove)
# radFov.py:58(__init__)                                                   ->       2    0.000    0.000  __init__.py:621(__len__)
#                                                                                5550    0.160    2.085  radFov.py:248(calcFieldPnt)
#                                                                                   2    0.000    0.000  radFov.py:346(slantRange)
#                                                                                5555    0.003    0.003  {isinstance}
#                                                                                   2    0.000    0.000  {numpy.core.multiarray.arange}
#                                                                                   3    0.000    0.000  {numpy.core.multiarray.array}
#                                                                                   6    0.000    0.000  {numpy.core.multiarray.zeros}
# radFov.py:248(calcFieldPnt)                                              ->    5550    0.113    0.114  geoPack.py:28(geodToGeoc)
#                                                                               10640    0.112    1.720  geoPack.py:307(calcDistPnt)
#                                                                               10640    0.068    0.085  radFov.py:375(calcAzOffBore)
#                                                                               10640    0.002    0.002  {abs}
#                                                                               10640    0.004    0.004  {math.asin}
#                                                                               10640    0.001    0.001  {math.degrees}
# geoPack.py:307(calcDistPnt)                                              ->   10640    0.208    0.209  geoPack.py:28(geodToGeoc)
#                                                                               10640    0.375    0.586  geoPack.py:69(geodToGeocAzEl)
#                                                                               10640    0.158    0.159  geoPack.py:138(gspToGcar)
#                                                                               10640    0.252    0.447  geoPack.py:180(gcarToLcar)
#                                                                               10640    0.205    0.206  geoPack.py:253(lspToLcar)
# geoPack.py:69(geodToGeocAzEl)                                            ->   10640    0.208    0.209  geoPack.py:28(geodToGeoc)
#                                                                               10640    0.002    0.002  {isinstance}
# geoPack.py:28(geodToGeoc)                                                ->   26830    0.003    0.003  {isinstance}
# geoPack.py:180(gcarToLcar)                                               ->   10640    0.194    0.195  geoPack.py:138(gspToGcar)
#                                                                               10640    0.001    0.001  {isinstance}
# geoPack.py:138(gspToGcar)                                                ->   21280    0.002    0.002  {isinstance}
# geoPack.py:253(lspToLcar)                                                ->   10640    0.002    0.002  {isinstance}
# radFov.py:375(calcAzOffBore)                                             ->   10640    0.002    0.002  {math.atan}
#                                                                               21280    0.004    0.004  {math.cos}
#                                                                               10640    0.001    0.001  {math.degrees}
#                                                                               53200    0.004    0.004  {math.radians}
#                                                                               31920    0.004    0.004  {math.sin}
#                                                                               10640    0.001    0.001  {math.sqrt}
# __init__.py:526(__init__)                                                ->       1    0.000    0.010  __init__.py:568(fillFromHdf5)
#                                                                                   2    0.000    0.002  dataset.py:258(__getitem__)
#                                                                                   1    0.000    0.001  files.py:123(__init__)
#                                                                                   1    0.000    0.000  files.py:156(close)
#                                                                                   3    0.000    0.000  group.py:120(__getitem__)
#                                                                                  11    0.000    0.000  weakref.py:48(remove)
#                                                                                   1    0.000    0.000  {method 'split' of 'str' objects}
#                                                                                   1    0.000    0.000  {numpy.core.multiarray.where}
# {isinstance}                                                             ->
# dataset.py:258(__getitem__)                                              ->      54    0.000    0.000  base.py:134(id)
#                                                                                  54    0.001    0.001  dataset.py:112(_g_shape)
#                                                                                  36    0.000    0.000  dataset.py:272(<genexpr>)
#                                                                                  18    0.000    0.000  dataset.py:273(<genexpr>)
#                                                                                  18    0.000    0.000  dataset.py:275(readtime_dtype)
#                                                                                  18    0.000    0.001  selections.py:29(select)
#                                                                                  18    0.000    0.000  selections.py:168(nselect)
#                                                                                  36    0.000    0.000  selections.py:239(mshape)
#                                                                                  42    0.000    0.000  weakref.py:48(remove)
#                                                                                  42    0.000    0.000  weakref.py:62(__contains__)
#                                                                                  42    0.000    0.000  weakref.py:79(__setitem__)
#                                                                                  18    0.000    0.000  {h5py.h5s.create_simple}
#                                                                                  18    0.000    0.001  {h5py.h5t.py_create}
#                                                                                  18    0.000    0.000  {isinstance}
#                                                                                  54    0.000    0.000  {len}
#                                                                                  18    0.007    0.007  {method 'read' of 'h5py.h5d.DatasetID' objects}
# __init__.py:568(fillFromHdf5)                                            ->      16    0.001    0.009  dataset.py:258(__getitem__)
#                                                                                  48    0.000    0.000  weakref.py:48(remove)
#                                                                                   1    0.000    0.000  {built-in method strptime}
#                                                                                   1    0.000    0.000  {len}
#                                                                                   1    0.000    0.000  {numpy.core.multiarray.where}
# {method 'read' of 'h5py.h5d.DatasetID' objects}                          ->
# {math.sin}                                                               ->
# {math.radians}                                                           ->
# {math.asin}                                                              ->
# {math.cos}                                                               ->
# {math.atan}                                                              ->
# {math.degrees}                                                           ->
# {abs}                                                                    ->
# {math.sqrt}                                                              ->
# selections.py:29(select)                                                 ->      18    0.000    0.000  selections.py:244(__init__)
#                                                                                  18    0.000    0.001  selections.py:250(__getitem__)
#                                                                                  18    0.000    0.000  {isinstance}
#                                                                                  18    0.000    0.000  {len}
# dataset.py:112(_g_shape)                                                 ->      54    0.000    0.000  base.py:134(id)
#                                                                                  54    0.000    0.000  weakref.py:48(remove)
#                                                                                  54    0.000    0.000  weakref.py:62(__contains__)
#                                                                                  54    0.000    0.000  weakref.py:79(__setitem__)
# selections.py:250(__getitem__)                                           ->      36    0.000    0.000  selections.py:163(shape)
#                                                                                  36    0.000    0.000  selections.py:267(<genexpr>)
#                                                                                  18    0.000    0.000  selections.py:494(_handle_simple)
#                                                                                  18    0.000    0.000  {isinstance}
#                                                                                  18    0.000    0.000  {method 'select_hyperslab' of 'h5py.h5s.SpaceID' objects}
#                                                                                  18    0.000    0.000  {zip}
# {h5py.h5t.py_create}                                                     ->      20    0.000    0.000  weakref.py:48(remove)
#                                                                                  38    0.000    0.000  weakref.py:62(__contains__)
#                                                                                  38    0.000    0.000  weakref.py:79(__setitem__)
# weakref.py:79(__setitem__)                                               ->     181    0.000    0.000  weakref.py:223(__new__)
#                                                                                 181    0.000    0.000  weakref.py:228(__init__)
# files.py:123(__init__)                                                   ->       3    0.000    0.000  base.py:49(_shared)
#                                                                                   1    0.000    0.000  files.py:12(make_fapl)
#                                                                                   1    0.000    0.000  files.py:41(make_fid)
#                                                                                   1    0.000    0.000  files.py:61(make_lapl)
#                                                                                   1    0.000    0.000  files.py:70(make_lcpl)
#                                                                                   1    0.000    0.000  group.py:16(__init__)
#                                                                                   1    0.000    0.000  weakref.py:48(remove)
#                                                                                   1    0.000    0.000  {isinstance}
#                                                                                   1    0.000    0.000  {method 'encode' of 'str' objects}
#                                                                                   1    0.000    0.000  {sys.getfilesystemencoding}
# selections.py:494(_handle_simple)                                        ->      18    0.000    0.000  selections.py:471(_expand_ellipsis)
#                                                                                  18    0.000    0.000  selections.py:540(_translate_slice)
#                                                                                  18    0.000    0.000  {isinstance}
#                                                                                  18    0.000    0.000  {len}
#                                                                                  72    0.000    0.000  {method 'append' of 'list' objects}
#                                                                                  18    0.000    0.000  {zip}
# {h5py.h5s.create_simple}                                                 ->      36    0.000    0.000  weakref.py:62(__contains__)
#                                                                                  36    0.000    0.000  weakref.py:79(__setitem__)
# weakref.py:62(__contains__)                                              ->
# selections.py:244(__init__)                                              ->      18    0.000    0.000  selections.py:147(__init__)
#                                                                                  54    0.000    0.000  selections.py:163(shape)
#                                                                                  18    0.000    0.000  {len}
# group.py:120(__getitem__)                                                ->       3    0.000    0.000  base.py:49(_shared)
#                                                                                   3    0.000    0.000  base.py:61(_e)
#                                                                                   3    0.000    0.000  base.py:134(id)
#                                                                                   3    0.000    0.000  dataset.py:185(__init__)
#                                                                                   3    0.000    0.000  {h5py.h5i.get_type}
#                                                                                   3    0.000    0.000  {h5py.h5o.open}
#                                                                                   3    0.000    0.000  {isinstance}
# files.py:41(make_fid)                                                    ->       1    0.000    0.000  {h5py.h5f.open}
# selections.py:147(__init__)                                              ->      18    0.000    0.000  {h5py.h5s.create_simple}
#                                                                                  18    0.000    0.000  {len}
#                                                                                  18    0.000    0.000  {method 'select_all' of 'h5py.h5s.SpaceID' objects}
# {h5py.h5f.open}                                                          ->       1    0.000    0.000  weakref.py:62(__contains__)
#                                                                                   1    0.000    0.000  weakref.py:79(__setitem__)
# files.py:156(close)                                                      ->       1    0.000    0.000  base.py:134(id)
#                                                                                   1    0.000    0.000  {method 'close' of 'h5py.h5f.FileID' objects}
# {method 'close' of 'h5py.h5f.FileID' objects}                            ->
# {h5py.h5o.open}                                                          ->       3    0.000    0.000  weakref.py:62(__contains__)
#                                                                                   3    0.000    0.000  weakref.py:79(__setitem__)
# weakref.py:228(__init__)                                                 ->
# selections.py:471(_expand_ellipsis)                                      ->      54    0.000    0.000  {len}
#                                                                                  18    0.000    0.000  {method 'extend' of 'list' objects}
#                                                                                  18    0.000    0.000  {sum}
# weakref.py:223(__new__)                                                  ->     181    0.000    0.000  {built-in method __new__ of type object at 0x88d8a0}
# weakref.py:48(remove)                                                    ->
# {h5py.h5p.create}                                                        ->       4    0.000    0.000  weakref.py:62(__contains__)
#                                                                                   4    0.000    0.000  weakref.py:79(__setitem__)
# dataset.py:185(__init__)                                                 ->       3    0.000    0.000  base.py:134(id)
#                                                                                   3    0.000    0.000  base.py:150(__init__)
#                                                                                   3    0.000    0.000  filters.py:156(get_filters)
#                                                                                   3    0.000    0.000  {method 'get_create_plist' of 'h5py.h5d.DatasetID' objects}
# dataset.py:275(readtime_dtype)                                           ->      18    0.000    0.000  {len}
# {built-in method strptime}                                               ->       1    0.000    0.000  _strptime.py:295(_strptime)
# {method 'get_create_plist' of 'h5py.h5d.DatasetID' objects}              ->       3    0.000    0.000  weakref.py:62(__contains__)
#                                                                                   3    0.000    0.000  weakref.py:79(__setitem__)
# files.py:12(make_fapl)                                                   ->       1    0.000    0.000  {h5py.h5p.create}
#                                                                                   1    0.000    0.000  {method 'set_fclose_degree' of 'h5py.h5p.PropFAID' objects}
# _strptime.py:295(_strptime)                                              ->       1    0.000    0.000  _strptime.py:27(_getlang)
#                                                                                   2    0.000    0.000  {len}
#                                                                                   1    0.000    0.000  {method 'end' of '_sre.SRE_Match' objects}
#                                                                                   1    0.000    0.000  {method 'get' of 'dict' objects}
#                                                                                   1    0.000    0.000  {method 'groupdict' of '_sre.SRE_Match' objects}
#                                                                                   1    0.000    0.000  {method 'iterkeys' of 'dict' objects}
#                                                                                   1    0.000    0.000  {method 'match' of '_sre.SRE_Pattern' objects}
#                                                                                   2    0.000    0.000  {method 'toordinal' of 'datetime.date' objects}
#                                                                                   1    0.000    0.000  {method 'weekday' of 'datetime.date' objects}
# files.py:61(make_lapl)                                                   ->       2    0.000    0.000  {h5py.h5p.create}
#                                                                                   1    0.000    0.000  {method 'set_elink_fapl' of 'h5py.h5p.PropLAID' objects}
#                                                                                   1    0.000    0.000  {method 'set_fclose_degree' of 'h5py.h5p.PropFAID' objects}
# base.py:49(_shared)                                                      ->       6    0.000    0.000  base.py:134(id)
# {built-in method __new__ of type object at 0x88d8a0}                     ->
# {method 'select_hyperslab' of 'h5py.h5s.SpaceID' objects}                ->
# selections.py:168(nselect)                                               ->      18    0.000    0.000  {method 'get_select_npoints' of 'h5py.h5s.SpaceID' objects}
# {numpy.core.multiarray.zeros}                                            ->
# radFov.py:346(slantRange)                                                ->
# selections.py:540(_translate_slice)                                      ->      18    0.000    0.000  {method 'indices' of 'slice' objects}
# files.py:70(make_lcpl)                                                   ->       1    0.000    0.000  {h5py.h5p.create}
#                                                                                   1    0.000    0.000  {method 'set_create_intermediate_group' of 'h5py.h5p.PropLCID' objects}
# {numpy.core.multiarray.array}                                            ->
# selections.py:163(shape)                                                 ->
# {zip}                                                                    ->
# filters.py:156(get_filters)                                              ->       3    0.000    0.000  {method 'get_nfilters' of 'h5py.h5p.PropDCID' objects}
#                                                                                   3    0.000    0.000  {range}
# _strptime.py:27(_getlang)                                                ->       1    0.000    0.000  locale.py:506(getlocale)
# locale.py:506(getlocale)                                                 ->       1    0.000    0.000  locale.py:407(_parse_localename)
#                                                                                   1    0.000    0.000  {_locale.setlocale}
# dataset.py:272(<genexpr>)                                                ->      18    0.000    0.000  {isinstance}
# base.py:134(id)                                                          ->
# {method 'get_select_npoints' of 'h5py.h5s.SpaceID' objects}              ->
# {len}                                                                    ->
# {sum}                                                                    ->      18    0.000    0.000  selections.py:474(<genexpr>)
# {method 'append' of 'list' objects}                                      ->
# dataset.py:273(<genexpr>)                                                ->      18    0.000    0.000  {isinstance}
# {method 'select_all' of 'h5py.h5s.SpaceID' objects}                      ->
# locale.py:407(_parse_localename)                                         ->       1    0.000    0.000  locale.py:339(normalize)
# locale.py:339(normalize)                                                 ->       1    0.000    0.000  {isinstance}
#                                                                                   2    0.000    0.000  {method 'get' of 'dict' objects}
#                                                                                   2    0.000    0.000  {method 'replace' of 'str' objects}
#                                                                                   1    0.000    0.000  {method 'translate' of 'str' objects}
# {numpy.core.multiarray.where}                                            ->
# {method 'indices' of 'slice' objects}                                    ->
# {method 'set_elink_fapl' of 'h5py.h5p.PropLAID' objects}                 ->
# {numpy.core.multiarray.arange}                                           ->
# selections.py:267(<genexpr>)                                             ->
# {method 'match' of '_sre.SRE_Pattern' objects}                           ->
# {method 'extend' of 'list' objects}                                      ->
# {method 'get_nfilters' of 'h5py.h5p.PropDCID' objects}                   ->
# {method 'set_fclose_degree' of 'h5py.h5p.PropFAID' objects}              ->
# base.py:61(_e)                                                           ->       3    0.000    0.000  {isinstance}
# selections.py:239(mshape)                                                ->
# {method 'groupdict' of '_sre.SRE_Match' objects}                         ->
# {method 'set_create_intermediate_group' of 'h5py.h5p.PropLCID' objects}  ->
# {h5py.h5i.get_type}                                                      ->
# {method 'split' of 'str' objects}                                        ->
# selections.py:474(<genexpr>)                                             ->
# base.py:150(__init__)                                                    ->
# {method 'encode' of 'str' objects}                                       ->
# group.py:16(__init__)                                                    ->       1    0.000    0.000  base.py:150(__init__)
# {method 'replace' of 'str' objects}                                      ->
# {range}                                                                  ->
# {method 'translate' of 'str' objects}                                    ->
# __init__.py:621(__len__)                                                 ->
# {method 'end' of '_sre.SRE_Match' objects}                               ->
# {sys.getfilesystemencoding}                                              ->
# {method 'weekday' of 'datetime.date' objects}                            ->
# {method 'toordinal' of 'datetime.date' objects}                          ->
# {_locale.setlocale}                                                      ->
# {method 'get' of 'dict' objects}                                         ->
# {method 'iterkeys' of 'dict' objects}                                    ->
# {method 'disable' of '_lsprof.Profiler' objects}                         ->
# <pstats.Stats instance at 0x7f26320>
